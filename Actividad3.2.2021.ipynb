# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name='2021', skiprows=3)
df.head()
# Out:
#        FECHA                   FOLIO                                  UUID  \
# 0 2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1 2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2 2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3 2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4 2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
#
#             RFC                               PROVEEDOR  \
# 0  BNM840515VB1          BANCO NACIONAL DE MEXICO, S.A.
# 1  BNM840515VB1          BANCO NACIONAL DE MEXICO, S.A.
# 2  ESI9612311E7  ELECTRONICOS Y SIMILARES, S.A. DE C.V.
# 3  BLE1512082R9            BEPENSA LEASING S.A. DE C.V.
# 4  BLE1512082R9            BEPENSA LEASING S.A. DE C.V.
#
#                  TIPO GASTO  \
# 0         COMISION BANCARIA
# 1         COMISION BANCARIA
# 2                   COMPRAS
# 3  ARRENDAMIENTO FINANCIERO
# ...

# %%
pd.options.display.max_columns=None

# %% [markdown]
# Me salto la cantidad de 3 filas para visualizar el nombre de las columnas y ver todas con sus nombres

# %%
data1=df.copy()

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           147
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# DESCRIPCION       0
# MP              654
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              0
# STATUS            0
# POLIZA         2372
# dtype: int64

# %%
data1["POLIZA"] =data1["POLIZA"].fillna(method="bfill")
# Out:
# C:\Users\jaque\AppData\Local\Temp\ipykernel_16368\868000157.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["POLIZA"] =data1["POLIZA"].fillna(method="bfill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA            0
# FOLIO          147
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# MP             654
# TC               0
# IMPORTE          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# POLIZA           6
# dtype: int64

# %%
data1["POLIZA"] =data1["POLIZA"].fillna(method="bfill")
# Out:
# C:\Users\jaque\AppData\Local\Temp\ipykernel_16368\417419777.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["POLIZA"] =data1["POLIZA"].fillna(method="bfill")

# %%
data1["POLIZA"] =data1["POLIZA"].fillna(method="ffill")
# Out:
# C:\Users\jaque\AppData\Local\Temp\ipykernel_16368\388502107.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["POLIZA"] =data1["POLIZA"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA            0
# FOLIO          147
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# MP             654
# TC               0
# IMPORTE          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# POLIZA           0
# dtype: int64

# %% [markdown]
# Primero se hace una limpieza por sustitución hacia atrás (bfill), es decir que tomé el ultimo valor y llene el anterior y luego una sustitucion hacia delante (ffill)

# %%
data1.head(30)
# Out:
#         FECHA                   FOLIO                                  UUID  \
# 0  2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1  2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2  2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3  2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4  2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# 5  2021-01-01                    4101  1BDD6B05-B42C-46D8-AF16-0D91FEDCE822
# 6  2021-01-01                   32322  60B3F20E-5A5E-4439-83C6-2F8052F90D2A
# 7  2021-01-01                 9231013  26928ED7-4CBE-4102-99A5-DE5CF2D92698
# 8  2021-01-01                 9231022  E6883E6F-6947-41DC-AF28-7027615DF8B4
# 9  2021-01-01                 9231026  A54AB33B-1D51-4213-8147-A001D3980B72
# 10 2021-01-01                    1747  23560FB4-B68F-4024-B02A-E755FA6BC6BE
# ...

# %%
data1["MP"] =data1["MP"].fillna("Pago")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA            0
# FOLIO          147
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# MP               0
# TC               0
# IMPORTE          0
# IVA              0
# RET ISR          0
# RET IVA          0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# POLIZA           0
# dtype: int64

# %%
data1["FOLIO"] =data1["FOLIO"].fillna("111111")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# dtype: int64

# %%
#Convertir DataFrame a CSV
data1.to_csv("BASELIMPIA2021.csv")
